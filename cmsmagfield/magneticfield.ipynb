# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import os
from tqdm import tqdm

import pandas as pd

# %%
dfc = pd.read_pickle("bfield_10cm_5deg.pkl.bz2")
dfc["x"] = dfc["rho"]*np.cos(dfc["phi"])
dfc["y"] = dfc["rho"]*np.sin(dfc["phi"])
dfc["bmag"] = (dfc.bx*dfc.bx+dfc.by*dfc.by+dfc.bz*dfc.bz)**0.5
dfc
# Out:
#          rho     z  phi            bx        by        bz           x  \
# 0          0 -1500    0 -2.971660e-18 -0.000012  0.025249    0.000000
# 1          0 -1500    5 -2.971660e-18 -0.000012  0.025249    0.000000
# 2          0 -1500   10 -2.971660e-18 -0.000012  0.025249   -0.000000
# 3          0 -1500   15 -2.971660e-18 -0.000012  0.025249   -0.000000
# 4          0 -1500   20 -2.971660e-18 -0.000012  0.025249    0.000000
# 5          0 -1500   25 -2.971660e-18 -0.000012  0.025249    0.000000
# 6          0 -1500   30 -2.971660e-18 -0.000012  0.025249    0.000000
# 7          0 -1500   35 -2.971660e-18 -0.000012  0.025249   -0.000000
# 8          0 -1500   40 -2.971660e-18 -0.000012  0.025249   -0.000000
# 9          0 -1500   45 -2.971660e-18 -0.000012  0.025249    0.000000
# 10         0 -1500   50 -2.971660e-18 -0.000012  0.025249    0.000000
# 11         0 -1500   55 -2.971660e-18 -0.000012  0.025249    0.000000
# 12         0 -1500   60 -2.971660e-18 -0.000012  0.025249   -0.000000
# 13         0 -1500   65 -2.971660e-18 -0.000012  0.025249   -0.000000
# 14         0 -1500   70 -2.971660e-18 -0.000012  0.025249    0.000000
# 15         0 -1500   75 -2.971660e-18 -0.000012  0.025249    0.000000
# 16         0 -1500   80 -2.971660e-18 -0.000012  0.025249   -0.000000
# 17         0 -1500   85 -2.971660e-18 -0.000012  0.025249   -0.000000
# 18         0 -1500   90 -2.971660e-18 -0.000012  0.025249   -0.000000
# 19         0 -1500   95 -2.971660e-18 -0.000012  0.025249    0.000000
# 20         0 -1500  100 -2.971660e-18 -0.000012  0.025249    0.000000
# 21         0 -1500  105 -2.971660e-18 -0.000012  0.025249   -0.000000
# 22         0 -1500  110 -2.971660e-18 -0.000012  0.025249   -0.000000
# 23         0 -1500  115 -2.971660e-18 -0.000012  0.025249   -0.000000
# 24         0 -1500  120 -2.971660e-18 -0.000012  0.025249    0.000000
# 25         0 -1500  125 -2.971660e-18 -0.000012  0.025249    0.000000
# 26         0 -1500  130 -2.971660e-18 -0.000012  0.025249   -0.000000
# 27         0 -1500  135 -2.971660e-18 -0.000012  0.025249   -0.000000
# 28         0 -1500  140 -2.971660e-18 -0.000012  0.025249   -0.000000
# 29         0 -1500  145 -2.971660e-18 -0.000012  0.025249    0.000000
# ...      ...   ...  ...           ...       ...       ...         ...
# 1972122  900  1500  210  0.000000e+00  0.000000  0.000000 -795.489726
# 1972123  900  1500  215  0.000000e+00  0.000000  0.000000  178.005623
# 1972124  900  1500  220  2.012810e-02  0.002422  0.015499  896.476654
# 1972125  900  1500  225  0.000000e+00  0.000000  0.000000  330.587431
# 1972126  900  1500  230 -1.561330e-02 -0.012934  0.015502 -708.926347
# 1972127  900  1500  235  0.000000e+00  0.000000  0.000000 -732.778625
# 1972128  900  1500  240  0.000000e+00  0.000000  0.000000  293.203175
# 1972129  900  1500  245  0.000000e+00  0.000000  0.000000  899.119932
# 1972130  900  1500  250  0.000000e+00  0.000000  0.000000  216.889475
# 1972131  900  1500  255  0.000000e+00  0.000000  0.000000 -776.073247
# 1972132  900  1500  260  0.000000e+00  0.000000  0.000000 -657.174741
# 1972133  900  1500  265  0.000000e+00  0.000000  0.000000  403.242000
# 1972134  900  1500  270  0.000000e+00  0.000000  0.000000  885.943756
# 1972135  900  1500  275  2.839080e-03 -0.020073  0.015501   99.375484
# 1972136  900  1500  280  0.000000e+00  0.000000  0.000000 -829.565622
# 1972137  900  1500  285  0.000000e+00  0.000000  0.000000 -570.008278
# 1972138  900  1500  290  0.000000e+00  0.000000  0.000000  506.186034
# 1972139  900  1500  295  1.944970e-02 -0.005706  0.015509  857.179951
# 1972140  900  1500  300  0.000000e+00  0.000000  0.000000  -19.886957
# 1972141  900  1500  305  0.000000e+00  0.000000  0.000000 -868.462307
# 1972142  900  1500  310  0.000000e+00  0.000000  0.000000 -472.812875
# 1972143  900  1500  315  0.000000e+00  0.000000  0.000000  600.224040
# 1972144  900  1500  320  0.000000e+00  0.000000  0.000000  813.334601
# 1972145  900  1500  325  0.000000e+00  0.000000  0.000000 -138.799500
# 1972146  900  1500  330  0.000000e+00  0.000000  0.000000 -892.078940
# 1972147  900  1500  335 -9.133630e-03  0.018106  0.015523 -367.298624
# 1972148  900  1500  340  0.000000e+00  0.000000  0.000000  683.701479
# 1972149  900  1500  345  1.746600e-02 -0.010309  0.015509  755.179135
# 1972150  900  1500  350  0.000000e+00  0.000000  0.000000 -255.269951
# 1972151  900  1500  355  0.000000e+00  0.000000  0.000000 -900.000000
#
#                   y      bmag
# 0          0.000000  0.025249
# 1         -0.000000  0.025249
# 2         -0.000000  0.025249
# 3          0.000000  0.025249
# 4          0.000000  0.025249
# 5         -0.000000  0.025249
# 6         -0.000000  0.025249
# 7         -0.000000  0.025249
# 8          0.000000  0.025249
# 9          0.000000  0.025249
# 10        -0.000000  0.025249
# 11        -0.000000  0.025249
# 12        -0.000000  0.025249
# 13         0.000000  0.025249
# 14         0.000000  0.025249
# 15        -0.000000  0.025249
# 16        -0.000000  0.025249
# 17        -0.000000  0.025249
# 18         0.000000  0.025249
# 19         0.000000  0.025249
# 20        -0.000000  0.025249
# 21        -0.000000  0.025249
# 22        -0.000000  0.025249
# 23         0.000000  0.025249
# 24         0.000000  0.025249
# 25        -0.000000  0.025249
# 26        -0.000000  0.025249
# 27         0.000000  0.025249
# 28         0.000000  0.025249
# 29         0.000000  0.025249
# ...             ...       ...
# 1972122  420.946667  0.000000
# 1972123  882.221060  0.000000
# 1972124   79.558841  0.025519
# 1972125 -837.085390  0.000000
# 1972126 -554.457784  0.025522
# 1972127  522.527977  0.000000
# 1972128  850.900639  0.000000
# 1972129  -39.791307  0.000000
# 1972130 -873.475218  0.000000
# 1972131 -455.752471  0.000000
# 1972132  614.915733  0.000000
# 1972133  804.609153  0.000000
# 1972134 -158.441352  0.000000
# 1972135 -894.496793  0.025520
# 1972136 -349.028479  0.000000
# 1972137  696.484431  0.000000
# 1972138  744.161071  0.000000
# 1972139 -274.303720  0.025522
# 1972140 -899.780256  0.000000
# 1972141 -236.163548  0.000000
# 1972142  765.798920  0.000000
# 1972143  670.619938  0.000000
# 1972144 -385.339885  0.000000
# 1972145 -889.232646  0.000000
# 1972146 -119.143466  0.000000
# 1972147  821.639654  0.025539
# 1972148  585.279666  0.000000
# 1972149 -489.596236  0.025532
# 1972150 -863.039543  0.000000
# 1972151   -0.027130  0.000000
#
# [1972152 rows x 9 columns]

# %%
df = dfc[(dfc.phi == 0) & (dfc.z > 0)]
df = df.sort_values(["z","rho"])
nx = df["z"].unique().shape[0]
ny = df["rho"].unique().shape[0]
X = df["z"].values.reshape(nx,ny).T
Y = df["rho"].values.reshape(nx,ny).T
Z = df["bmag"].values.reshape(nx,ny).T
fig, ax = plt.subplots(figsize=(12,7))
C = ax.pcolormesh(X,Y,Z,cmap="cividis")
ax.set_aspect(1.0)
fig.colorbar(C,shrink=0.85);

# %%
# constants 
c = 3.0e8 # m/s

class Coordinate(object):
    def __init__(self,x,y,z):
        self.x = x
        self.y = y
        self.z = z

    def update(self,coord):
        self.x += coord.x
        self.y += coord.y
        self.z += coord.z

    def __repr__(self):
        return "<{:.3f}, {:.3f}, {:.3f}>".format(self.x,self.y,self.z)

    def __mul__(self,factor):
        return Coordinate(
                self.x*factor,
                self.y*factor,
                self.z*factor,
                )

def cross_product(c1,c2):
    x =   c1.y*c2.z - c1.z*c2.y
    y = -(c1.x*c2.z - c1.z*c2.x)
    z =   c1.x*c2.y - c1.y*c2.x
    return Coordinate(x,y,z)

def to_cylindrical_rounded(c1):
    x,y,z = 100.*c1.x,100.*c1.y,100.*c1.z
    rho = np.sqrt(x*x+y*y)
    phi = np.arctan2(y,x)
    rho = int(rho/10)*10
    z = int(z/10)*10
    phi = int(360.*phi/5/(2*3.141592))*5
    return rho,z,phi

class Particle(object):
    def __init__(self,x0,v0,mev):
        self.x0 = x0
        self.v0 = v0
        # self.qoverm = 9.6e7 # 9.6e7 C/kg for proton; 6.4e8 C/kg for pi+
        # self.qoverm = 1.8e11 / (mev/0.5)
        self.qoverm = 8.5e8 / (mev/106.)
        # self.qoverm = 6.4e8 # 9.6e7 C/kg for proton; 6.4e8 C/kg for pi+
        # self.qoverm = 1.76e11 # C/kg for electron
        # self.qoverm = 4.8e7
        # self.qoverm = 1.

    def __repr__(self):
        return "x={}, v={}".format(str(self.x0),str(self.v0))

    def propagate(self,bvec,dt=1.):
        # self.x0.update(1,1,1)
        # self.v0.update(1,1,1)

        dv = cross_product(self.v0,bvec)*dt*self.qoverm
        self.v0.update(dv)
        self.x0.update(self.v0*dt)
