# %%
# %matplotlib inline

import os
import sys
import numpy as np
import pandas as pd
import json
from pprint import pprint
from scipy import stats
import gzip

from tqdm.auto import tqdm

import matplotlib.pyplot as plt

# %%
# ! curl "https://data.transportation.gov/api/views/8ect-6jqj/rows.json?accessType=DOWNLOAD" | gzip -1 -c > data.json.gz

# %%
def get_header_df(fname):
    lines_sofar = []
    with gzip.open(fname) as fh:
        for iline,line in enumerate(tqdm(fh)):
            line = line.decode()
            if line.strip().startswith('"data" :'):
                break
            lines_sofar.append(line)
    lines_sofar[-1] = lines_sofar[-1].replace(",","}")
    js = json.loads("".join(lines_sofar))
    return pd.DataFrame(js["meta"]["view"]["columns"])

def get_column_names(fname):
    return get_header_df(fname)["fieldName"].values.tolist()

column_names = get_column_names("data.json.gz")
def get_df_from_chunk(lines):
    js = '{"data": [%s]}' % (",".join("[%s]"%line for line in lines))
    df = pd.DataFrame(json.loads(js)["data"],columns=column_names)
    df = df[df.columns[~df.columns.str.startswith(":")]]

    ks = ["o_zone","d_zone","int_id","section_id","direction","movement","section_id"]
    for k in ks:
        df[k] = pd.to_numeric(df[k],errors="coerce").fillna(-1).astype(int)

    for k in ["vehicle_id","frame_id","total_frames","global_time","v_class","lane_id","preceding","following"]:
        df[k] = df[k].astype(int)

    for k in ["local_x","local_y","global_x","global_y","v_length","v_width","v_vel","v_acc","space_headway","time_headway"]:
        df[k] = df[k].astype(float)

    location_map = {'i-80': 0, 'lankershim': 1, 'peachtree': 2, 'us-101': 3}
    df["location"] = df["location"].map(location_map)
    return df
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
meta = get_header_df("data.json.gz")
meta.to_json("meta.json.gz")
meta
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
#            id           name dataTypeName      fieldName  position  \
# 0          -1            sid    meta_data           :sid         0
# 1          -1             id    meta_data            :id         0
# 2          -1       position    meta_data      :position         0
# 3          -1     created_at    meta_data    :created_at         0
# 4          -1   created_meta    meta_data  :created_meta         0
# 5          -1     updated_at    meta_data    :updated_at         0
# 6          -1   updated_meta    meta_data  :updated_meta         0
# 7          -1           meta    meta_data          :meta         0
# 8   372619689     Vehicle_ID       number     vehicle_id         1
# 9   372619690       Frame_ID       number       frame_id         2
# 10  372619691   Total_Frames       number   total_frames         3
# 11  372619692    Global_Time       number    global_time         4
# 12  372619693        Local_X       number        local_x         5
# 13  372619694        Local_Y       number        local_y         6
# 14  372619695       Global_X       number       global_x         7
# 15  372619696       Global_Y       number       global_y         8
# 16  372619697       v_length       number       v_length         9
# 17  372619698        v_Width       number        v_width        10
# 18  372619699        v_Class       number        v_class        11
# 19  372619700          v_Vel       number          v_vel        12
# 20  372619701          v_Acc       number          v_acc        13
# 21  372619702        Lane_ID       number        lane_id        14
# 22  372619703         O_Zone         text         o_zone        15
# 23  372619704         D_Zone         text         d_zone        16
# 24  372619705         Int_ID         text         int_id        17
# 25  372619706     Section_ID         text     section_id        18
# 26  372619707      Direction         text      direction        19
# 27  372619708       Movement         text       movement        20
# 28  372619709      Preceding       number      preceding        21
# 29  372619710      Following       number      following        22
# 30  372619711  Space_Headway       number  space_headway        23
# 31  372619712   Time_Headway       number   time_headway        24
# 32  372619713       Location         text       location        25
#
#    renderTypeName                                             format  \
# 0       meta_data                                                 {}
# 1       meta_data                                                 {}
# 2       meta_data                                                 {}
# 3       meta_data                                                 {}
# 4       meta_data                                                 {}
# 5       meta_data                                                 {}
# 6       meta_data                                                 {}
# 7       meta_data                                                 {}
# 8          number  {'precisionStyle': 'standard', 'noCommas': 'tr...
# 9          number  {'precisionStyle': 'standard', 'noCommas': 'tr...
# 10         number  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 11         number  {'precisionStyle': 'standard', 'noCommas': 'tr...
# 12         number  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 13         number  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 14         number  {'precisionStyle': 'standard', 'noCommas': 'tr...
# 15         number  {'precisionStyle': 'standard', 'noCommas': 'tr...
# 16         number  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 17         number  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 18         number  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 19         number  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 20         number  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 21         number  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 22           text         {'displayStyle': 'plain', 'align': 'left'}
# 23           text         {'displayStyle': 'plain', 'align': 'left'}
# 24           text         {'displayStyle': 'plain', 'align': 'left'}
# 25           text         {'displayStyle': 'plain', 'align': 'left'}
# 26           text         {'displayStyle': 'plain', 'align': 'left'}
# 27           text         {'displayStyle': 'plain', 'align': 'left'}
# 28         number  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 29         number  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 30         number  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 31         number  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 32           text         {'displayStyle': 'plain', 'align': 'left'}
#
#        flags                                        description  \
# 0   [hidden]                                                NaN
# 1   [hidden]                                                NaN
# 2   [hidden]                                                NaN
# 3   [hidden]                                                NaN
# 4   [hidden]                                                NaN
# 5   [hidden]                                                NaN
# 6   [hidden]                                                NaN
# 7   [hidden]                                                NaN
# 8        NaN  Vehicle identification number (ascending by ti...
# 9        NaN   Frame Identification number (ascending by sta...
# 10       NaN   Total number of frames in which the vehicle a...
# 11       NaN    Elapsed time in milliseconds since Jan 1, 1970.
# 12       NaN  Lateral (X) coordinate of the front center of ...
# 13       NaN  Longitudinal (Y) coordinate of the front cente...
# 14       NaN  X Coordinate of the front center of the vehicl...
# 15       NaN  Y Coordinate of the front center of the vehicl...
# 16       NaN                          Length of vehicle in feet
# 17       NaN                           Width of vehicle in feet
# 18       NaN  Vehicle type: 1 - motorcycle, 2 - auto, 3 - tr...
# 19       NaN  Instantaneous velocity of vehicle in feet/second.
# 20       NaN  Instantaneous acceleration of vehicle in feet/...
# 21       NaN  Current lane position of vehicle. Lane 1 is fa...
# 22       NaN  Origin zones of the vehicles, i.e., the place ...
# 23       NaN  Destination zones of the vehicles, i.e., the p...
# 24       NaN  Intersection in which the vehicle is traveling...
# 25       NaN  Section in which the vehicle is traveling. Lan...
# 26       NaN   Moving direction of the vehicle. 1 - east-bou...
# 27       NaN  Movement of the vehicle. 1 - through (TH), 2 -...
# 28       NaN  Vehicle ID of the lead vehicle in the same lan...
# 29       NaN  Vehicle ID of the vehicle following the subjec...
# 30       NaN  Space Headway in feet. Spacing provides the di...
# 31       NaN  Time Headway in seconds. Time Headway provides...
# 32       NaN                         Name of street or freeway
#
#     tableColumnId  width                                     cachedContents
# 0             NaN    NaN                                                NaN
# 1             NaN    NaN                                                NaN
# 2             NaN    NaN                                                NaN
# 3             NaN    NaN                                                NaN
# 4             NaN    NaN                                                NaN
# 5             NaN    NaN                                                NaN
# 6             NaN    NaN                                                NaN
# 7             NaN    NaN                                                NaN
# 8      52723321.0  100.0  {'largest': '3366', 'non_null': 11850526, 'ave...
# 9      52723322.0  100.0  {'largest': '11691', 'non_null': 11850526, 'av...
# 10     52723323.0  100.0  {'largest': '2434', 'non_null': 11850526, 'ave...
# 11     52723324.0  100.0  {'largest': '1118937747000', 'non_null': 11850...
# 12     52723325.0  100.0  {'largest': '160.884', 'non_null': 11850526, '...
# 13     52723326.0  100.0  {'largest': '2235.252', 'non_null': 11850526, ...
# 14     52723327.0  100.0  {'largest': '6452740.916', 'non_null': 1185052...
# 15     52723328.0  100.0  {'largest': '2134845.191', 'non_null': 1185052...
# 16     52723329.0  100.0  {'largest': '77.7', 'non_null': 11850526, 'ave...
# 17     52723336.0  100.0  {'largest': '8.5', 'non_null': 11850526, 'aver...
# 18     52723344.0  100.0  {'largest': '3', 'non_null': 11850526, 'averag...
# 19     52723345.0  100.0  {'largest': '95.3', 'non_null': 11850526, 'ave...
# 20     52723346.0  100.0  {'largest': '15.84', 'non_null': 11850526, 'av...
# 21     52723362.0  100.0  {'largest': '9999', 'non_null': 11850526, 'ave...
# 22     52723363.0  100.0  {'largest': 'NA', 'non_null': 9476656, 'null':...
# 23     52723364.0  100.0  {'largest': 'NA', 'non_null': 9476656, 'null':...
# 24     52723365.0  100.0  {'largest': 'NA', 'non_null': 9476656, 'null':...
# 25     52723366.0  100.0  {'largest': 'NA', 'non_null': 9476656, 'null':...
# 26     52723368.0  100.0  {'largest': 'NA', 'non_null': 9476656, 'null':...
# 27     52723369.0  100.0  {'largest': 'NA', 'non_null': 9476656, 'null':...
# 28     52723370.0  100.0  {'largest': '3366', 'non_null': 11850526, 'ave...
# 29     52723402.0  100.0  {'largest': '3366', 'non_null': 11850526, 'ave...
# 30     52723403.0  100.0  {'largest': '1855.75', 'non_null': 11850526, '...
# 31     52723404.0  100.0  {'largest': '31864.08', 'non_null': 11850526, ...
# 32     52723419.0  100.0  {'largest': 'us-101', 'non_null': 11850526, 'n...

# %%
remake_parquet = False
if remake_parquet:
    data_lines = []
    dfs = []
    in_data = False
    ichunk = 0
    outdir = "outputs/"
    os.system("mkdir -p {}".format(outdir))
    with gzip.open("data.json.gz") as fh:
        for iline,line in enumerate(tqdm(fh)):

            line = line.decode()
            if not in_data:
                if line.strip().startswith('"data" :'):
                    in_data = True

            if in_data:
                line = line.replace('"data" : [ [ ',"",1).lstrip(",[ ").rstrip(" ]\n")
                data_lines.append(line)

            if len(data_lines) > 250000:
    #             dfs.append(get_df_from_chunk(data_lines))
                df = get_df_from_chunk(data_lines)
                df.to_parquet("{}/df_{}.parquet".format(outdir,ichunk),compression="lz4")
                ichunk += 1
                data_lines = []
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
